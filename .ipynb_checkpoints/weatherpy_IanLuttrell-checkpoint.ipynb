# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metrics"
# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="
print(query_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=640a70a6129d5a91e4f8251f720a9800&units=metrics&q=

# %%
response=requests.get(query_url+"new york")
json=response.json()
print(json)
# print(json['main']['temp_max'])
# Out:
# {'coord': {'lon': -73.99, 'lat': 40.73}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 296.31, 'pressure': 1011, 'humidity': 57, 'temp_min': 293.71, 'temp_max': 299.15}, 'visibility': 16093, 'wind': {'speed': 3.1, 'deg': 200}, 'clouds': {'all': 1}, 'dt': 1569451398, 'sys': {'type': 1, 'id': 4610, 'message': 0.0116, 'country': 'US', 'sunrise': 1569408368, 'sunset': 1569451756}, 'timezone': -14400, 'id': 5128581, 'name': 'New York', 'cod': 200}

# %%
city_data = []
city_counter = 0
set_counter = 1
for city in cities:
    json = requests.get(query_url + city).json()
    city_counter = city_counter + 1
    try:
        tempmax=json['main']['temp_max']
        humidity=json['main']["humidity"]
        speed=json['wind']["speed"]
        cloudiness=json["clouds"]["all"]
        lat=json["coord"]["lat"]
        country=json['sys']["country"]
        date=json['dt']
        lon=json["coord"]["lon"]
    except:
        print("City not found skipping...")
    if city_counter == 50:
        city_counter = 0
        set_counter = set_counter + 1
    city_data.append([city,cloudiness,country,date,humidity,lat,lon,tempmax,speed])
    #        data.append([city,temp,temp1,temp2,temp3,temp6,temp4,temp5,temp7])
    print(f"Processing Record {city_counter} of set {set_counter} || {city}")
    time.sleep(.1)
#len(city_data)
# Out:
# Processing Record 1 of set 1 || camalu
# Processing Record 2 of set 1 || ushuaia
# Processing Record 3 of set 1 || bethel
# Processing Record 4 of set 1 || thompson
# Processing Record 5 of set 1 || kahului
# Processing Record 6 of set 1 || ahipara
# Processing Record 7 of set 1 || esperance
# Processing Record 8 of set 1 || sangar
# Processing Record 9 of set 1 || makakilo city
# Processing Record 10 of set 1 || chokurdakh
# City not found skipping...
# Processing Record 11 of set 1 || yeletskiy
# Processing Record 12 of set 1 || lilongwe
# Processing Record 13 of set 1 || punta arenas
# Processing Record 14 of set 1 || saskylakh
# Processing Record 15 of set 1 || atuona
# City not found skipping...
# Processing Record 16 of set 1 || vreed en hoop
# Processing Record 17 of set 1 || eureka
# Processing Record 18 of set 1 || mahebourg
# Processing Record 19 of set 1 || dikson
# Processing Record 20 of set 1 || santa cruz
# Processing Record 21 of set 1 || hobart
# Processing Record 22 of set 1 || pevek
# City not found skipping...
# Processing Record 23 of set 1 || tsihombe
# Processing Record 24 of set 1 || vaini
# Processing Record 25 of set 1 || san ramon
# Processing Record 26 of set 1 || luderitz
# Processing Record 27 of set 1 || bathsheba
# Processing Record 28 of set 1 || mantua
# City not found skipping...
# Processing Record 29 of set 1 || atyuryevo
# Processing Record 30 of set 1 || ancud
# Processing Record 31 of set 1 || saint-philippe
# Processing Record 32 of set 1 || castro
# Processing Record 33 of set 1 || locri
# Processing Record 34 of set 1 || baculongan
# Processing Record 35 of set 1 || mataura
# Processing Record 36 of set 1 || algeciras
# Processing Record 37 of set 1 || bluff
# Processing Record 38 of set 1 || ahmadpur east
# Processing Record 39 of set 1 || darnah
# Processing Record 40 of set 1 || albany
# Processing Record 41 of set 1 || egvekinot
# Processing Record 42 of set 1 || jamestown
# City not found skipping...
# Processing Record 43 of set 1 || skalistyy
# Processing Record 44 of set 1 || aykhal
# Processing Record 45 of set 1 || madingou
# Processing Record 46 of set 1 || rikitea
# Processing Record 47 of set 1 || puerto ayora
# Processing Record 48 of set 1 || bredasdorp
# Processing Record 49 of set 1 || omboue
# Processing Record 0 of set 2 || busselton
# Processing Record 1 of set 2 || yellowknife
# City not found skipping...
# Processing Record 2 of set 2 || belushya guba
# Processing Record 3 of set 2 || kiama
# City not found skipping...
# Processing Record 4 of set 2 || sentyabrskiy
# Processing Record 5 of set 2 || vestmannaeyjar
# Processing Record 6 of set 2 || iqaluit
# City not found skipping...
# Processing Record 7 of set 2 || illoqqortoormiut
# Processing Record 8 of set 2 || roros
# Processing Record 9 of set 2 || bethlehem
# Processing Record 10 of set 2 || hasaki
# Processing Record 11 of set 2 || lebu
# Processing Record 12 of set 2 || faya
# Processing Record 13 of set 2 || chuy
# Processing Record 14 of set 2 || georgetown
# Processing Record 15 of set 2 || honningsvag
# Processing Record 16 of set 2 || fortuna
# Processing Record 17 of set 2 || ponta do sol
# Processing Record 18 of set 2 || hilo
# Processing Record 19 of set 2 || kokkola
# Processing Record 20 of set 2 || port elizabeth
# Processing Record 21 of set 2 || butaritari
# Processing Record 22 of set 2 || tilichiki
# City not found skipping...
# Processing Record 23 of set 2 || pemangkat
# Processing Record 24 of set 2 || ilulissat
# Processing Record 25 of set 2 || lorengau
# Processing Record 26 of set 2 || new norfolk
# Processing Record 27 of set 2 || port alfred
# Processing Record 28 of set 2 || piacabucu
# Processing Record 29 of set 2 || angoram
# Processing Record 30 of set 2 || carnarvon
# Processing Record 31 of set 2 || mackay
# Processing Record 32 of set 2 || klaksvik
# Processing Record 33 of set 2 || kirakira
# Processing Record 34 of set 2 || chiredzi
# Processing Record 35 of set 2 || khatanga
# Processing Record 36 of set 2 || zhigansk
# Processing Record 37 of set 2 || codrington
# Processing Record 38 of set 2 || praya
# Processing Record 39 of set 2 || neepawa
# Processing Record 40 of set 2 || buraydah
# Processing Record 41 of set 2 || boffa
# Processing Record 42 of set 2 || chettipalaiyam
# City not found skipping...
# Processing Record 43 of set 2 || palabuhanratu
# Processing Record 44 of set 2 || jatiroto
# Processing Record 45 of set 2 || salalah
# Processing Record 46 of set 2 || cape town
# Processing Record 47 of set 2 || isangel
# Processing Record 48 of set 2 || bacolod
# Processing Record 49 of set 2 || zelezna ruda
# Processing Record 0 of set 3 || halacho
# Processing Record 1 of set 3 || aljezur
# Processing Record 2 of set 3 || vila franca do campo
# Processing Record 3 of set 3 || zhicheng
# Processing Record 4 of set 3 || kaitangata
# City not found skipping...
# Processing Record 5 of set 3 || attawapiskat
# Processing Record 6 of set 3 || east london
# Processing Record 7 of set 3 || faanui
# Processing Record 8 of set 3 || truro
# City not found skipping...
# Processing Record 9 of set 3 || tasbuget
# Processing Record 10 of set 3 || cabo san lucas
# Processing Record 11 of set 3 || tual
# Processing Record 12 of set 3 || zhanaozen
# Processing Record 13 of set 3 || lata
# Processing Record 14 of set 3 || zaysan
# Processing Record 15 of set 3 || borovoy
# Processing Record 16 of set 3 || port lincoln
# Processing Record 17 of set 3 || mana
# Processing Record 18 of set 3 || cabra
# Processing Record 19 of set 3 || porto belo
# Processing Record 20 of set 3 || daru
# Processing Record 21 of set 3 || severo-kurilsk
# Processing Record 22 of set 3 || hit
# Processing Record 23 of set 3 || yining
# Processing Record 24 of set 3 || kalmunai
# City not found skipping...
# Processing Record 25 of set 3 || nizhneyansk
# Processing Record 26 of set 3 || makokou
# Processing Record 27 of set 3 || chara
# Processing Record 28 of set 3 || kikwit
# Processing Record 29 of set 3 || gweta
# Processing Record 30 of set 3 || tiksi
# Processing Record 31 of set 3 || sydney
# Processing Record 32 of set 3 || qaanaaq
# Processing Record 33 of set 3 || evensk
# City not found skipping...
# Processing Record 34 of set 3 || taolanaro
# City not found skipping...
# Processing Record 35 of set 3 || bengkulu
# City not found skipping...
# Processing Record 36 of set 3 || aflu
# Processing Record 37 of set 3 || kapaa
# Processing Record 38 of set 3 || nikolskoye
# Processing Record 39 of set 3 || tomatlan
# Processing Record 40 of set 3 || aklavik
# Processing Record 41 of set 3 || bambous virieux
# City not found skipping...
# Processing Record 42 of set 3 || kamenskoye
# Processing Record 43 of set 3 || sioux lookout
# Processing Record 44 of set 3 || avarua
# City not found skipping...
# Processing Record 45 of set 3 || karpuninskiy
# Processing Record 46 of set 3 || tuktoyaktuk
# Processing Record 47 of set 3 || susangerd
# Processing Record 48 of set 3 || chumikan
# Processing Record 49 of set 3 || college
# Processing Record 0 of set 4 || guarapari
# Processing Record 1 of set 4 || necochea
# Processing Record 2 of set 4 || tecoanapa
# Processing Record 3 of set 4 || tazovskiy
# Processing Record 4 of set 4 || tabuk
# Processing Record 5 of set 4 || kabo
# Processing Record 6 of set 4 || ayan
# Processing Record 7 of set 4 || coronado
# Processing Record 8 of set 4 || cherskiy
# Processing Record 9 of set 4 || arraial do cabo
# Processing Record 10 of set 4 || norman wells
# Processing Record 11 of set 4 || saint-francois
# Processing Record 12 of set 4 || barrow
# Processing Record 13 of set 4 || takoradi
# Processing Record 14 of set 4 || varhaug
# City not found skipping...
# Processing Record 15 of set 4 || olafsvik
# City not found skipping...
# Processing Record 16 of set 4 || satitoa
# Processing Record 17 of set 4 || tasiilaq
# Processing Record 18 of set 4 || osmena
# Processing Record 19 of set 4 || kieta
# Processing Record 20 of set 4 || carutapera
# Processing Record 21 of set 4 || kosum phisai
# Processing Record 22 of set 4 || safford
# Processing Record 23 of set 4 || monticello
# City not found skipping...
# Processing Record 24 of set 4 || vaitupu
# Processing Record 25 of set 4 || likasi
# Processing Record 26 of set 4 || latung
# Processing Record 27 of set 4 || usinsk
# Processing Record 28 of set 4 || barcelos
# Processing Record 29 of set 4 || port blair
# Processing Record 30 of set 4 || roald
# Processing Record 31 of set 4 || viedma
# Processing Record 32 of set 4 || calvinia
# Processing Record 33 of set 4 || rorvik
# City not found skipping...
# Processing Record 34 of set 4 || grand river south east
# Processing Record 35 of set 4 || gat
# Processing Record 36 of set 4 || upernavik
# Processing Record 37 of set 4 || provideniya
# Processing Record 38 of set 4 || carmo do rio claro
# Processing Record 39 of set 4 || havelock
# Processing Record 40 of set 4 || beringovskiy
# Processing Record 41 of set 4 || mount isa
# City not found skipping...
# Processing Record 42 of set 4 || saleaula
# City not found skipping...
# Processing Record 43 of set 4 || mys shmidta
# City not found skipping...
# Processing Record 44 of set 4 || tabiauea
# Processing Record 45 of set 4 || antofagasta
# Processing Record 46 of set 4 || gravdal
# Processing Record 47 of set 4 || ostrovnoy
# Processing Record 48 of set 4 || lagoa
# City not found skipping...
# Processing Record 49 of set 4 || goycay
# Processing Record 0 of set 5 || paamiut
# Processing Record 1 of set 5 || hermanus
# Processing Record 2 of set 5 || neiafu
# Processing Record 3 of set 5 || kavieng
# Processing Record 4 of set 5 || coria
# Processing Record 5 of set 5 || port hedland
# Processing Record 6 of set 5 || tshane
# Processing Record 7 of set 5 || tarata
# Processing Record 8 of set 5 || lumphat
# Processing Record 9 of set 5 || saint-joseph
# City not found skipping...
# Processing Record 10 of set 5 || macaboboni
# Processing Record 11 of set 5 || dodge city
# Processing Record 12 of set 5 || hokitika
# Processing Record 13 of set 5 || kodiak
# Processing Record 14 of set 5 || balikpapan
# Processing Record 15 of set 5 || hithadhoo
# Processing Record 16 of set 5 || mirnyy
# Processing Record 17 of set 5 || kiunga
# Processing Record 18 of set 5 || cidreira
# Processing Record 19 of set 5 || saint george
# Processing Record 20 of set 5 || kapit
# Processing Record 21 of set 5 || puerto narino
# Processing Record 22 of set 5 || lufilufi
# City not found skipping...
# Processing Record 23 of set 5 || abomsa
# Processing Record 24 of set 5 || mwinilunga
# City not found skipping...
# Processing Record 25 of set 5 || barentsburg
# Processing Record 26 of set 5 || nadym
# Processing Record 27 of set 5 || victoria
# Processing Record 28 of set 5 || berdigestyakh
# Processing Record 29 of set 5 || kolyvan
# Processing Record 30 of set 5 || eregli
# Processing Record 31 of set 5 || henties bay
# Processing Record 32 of set 5 || iwanai
# Processing Record 33 of set 5 || guaymas
# Processing Record 34 of set 5 || tura
# Processing Record 35 of set 5 || coihaique
# Processing Record 36 of set 5 || san patricio
# Processing Record 37 of set 5 || airai
# Processing Record 38 of set 5 || vermillion
# Processing Record 39 of set 5 || svetlaya
# Processing Record 40 of set 5 || bosobolo
# Processing Record 41 of set 5 || walvis bay
# Processing Record 42 of set 5 || karasuk
# Processing Record 43 of set 5 || los llanos de aridane
# Processing Record 44 of set 5 || kalaleh
# Processing Record 45 of set 5 || riyadh
# Processing Record 46 of set 5 || ribeira grande
# Processing Record 47 of set 5 || san carlos de bariloche
# Processing Record 48 of set 5 || cap malheureux
# Processing Record 49 of set 5 || comodoro rivadavia
# Processing Record 0 of set 6 || zhezkazgan
# Processing Record 1 of set 6 || la ronge
# City not found skipping...
# Processing Record 2 of set 6 || gorno-chuyskiy
# Processing Record 3 of set 6 || camopi
# City not found skipping...
# Processing Record 4 of set 6 || karakendzha
# Processing Record 5 of set 6 || veraval
# Processing Record 6 of set 6 || anajatuba
# Processing Record 7 of set 6 || madimba
# Processing Record 8 of set 6 || mayo
# Processing Record 9 of set 6 || limon
# Processing Record 10 of set 6 || yulara
# Processing Record 11 of set 6 || altus
# Processing Record 12 of set 6 || sabang
# Processing Record 13 of set 6 || sherlovaya gora
# Processing Record 14 of set 6 || georgiyevskoye
# Processing Record 15 of set 6 || guerrero negro
# Processing Record 16 of set 6 || nizhniy kuranakh
# Processing Record 17 of set 6 || mayumba
# Processing Record 18 of set 6 || vanavara
# Processing Record 19 of set 6 || cairns
# City not found skipping...
# Processing Record 20 of set 6 || tumannyy
# Processing Record 21 of set 6 || soe
# Processing Record 22 of set 6 || husavik
# City not found skipping...
# Processing Record 23 of set 6 || tulcingo
# City not found skipping...
# Processing Record 24 of set 6 || babanusah
# Processing Record 25 of set 6 || narsaq
# City not found skipping...
# Processing Record 26 of set 6 || bolshoy tsaryn
# Processing Record 27 of set 6 || surgut
# City not found skipping...
# Processing Record 28 of set 6 || acarau
# Processing Record 29 of set 6 || russell
# Processing Record 30 of set 6 || chapais
# City not found skipping...
# Processing Record 31 of set 6 || kazalinsk
# Processing Record 32 of set 6 || lavrentiya
# Processing Record 33 of set 6 || huarmey
# Processing Record 34 of set 6 || tiarei
# Processing Record 35 of set 6 || san ramon de la nueva oran
# Processing Record 36 of set 6 || molokovo
# Processing Record 37 of set 6 || colares
# City not found skipping...
# Processing Record 38 of set 6 || jiddah
# Processing Record 39 of set 6 || pasir gudang
# Processing Record 40 of set 6 || mirador
# Processing Record 41 of set 6 || lasa
# Processing Record 42 of set 6 || awjilah
# Processing Record 43 of set 6 || vyshkov
# Processing Record 44 of set 6 || ginda
# Processing Record 45 of set 6 || marsh harbour
# Processing Record 46 of set 6 || hovd
# Processing Record 47 of set 6 || sisimiut
# Processing Record 48 of set 6 || vestmanna
# Processing Record 49 of set 6 || alekseyevskoye
# Processing Record 0 of set 7 || richards bay
# Processing Record 1 of set 7 || asyut
# City not found skipping...
# Processing Record 2 of set 7 || catamarca
# City not found skipping...
# Processing Record 3 of set 7 || svetlyy
# Processing Record 4 of set 7 || ponta delgada
# Processing Record 5 of set 7 || iranshahr
# City not found skipping...
# Processing Record 6 of set 7 || ijaki
# Processing Record 7 of set 7 || burnie
# Processing Record 8 of set 7 || badajoz
# Processing Record 9 of set 7 || nantucket
# Processing Record 10 of set 7 || igrim
# Processing Record 11 of set 7 || etah
# Processing Record 12 of set 7 || agirish
# Processing Record 13 of set 7 || dalby
# Processing Record 14 of set 7 || novorudnyy
# Processing Record 15 of set 7 || torbay
# Processing Record 16 of set 7 || byron bay
# Processing Record 17 of set 7 || cockburn town
# Processing Record 18 of set 7 || saint-leu
# City not found skipping...
# Processing Record 19 of set 7 || bokspits
# Processing Record 20 of set 7 || solvychegodsk
# Processing Record 21 of set 7 || auki
# Processing Record 22 of set 7 || kodinsk
# Processing Record 23 of set 7 || dixon
# Processing Record 24 of set 7 || kihei
# Processing Record 25 of set 7 || tutoia
# Processing Record 26 of set 7 || palmer
# Processing Record 27 of set 7 || gondanglegi
# Processing Record 28 of set 7 || half moon bay
# Processing Record 29 of set 7 || tommot
# Processing Record 30 of set 7 || karratha
# Processing Record 31 of set 7 || praia da vitoria
# City not found skipping...
# Processing Record 32 of set 7 || orgun
# Processing Record 33 of set 7 || saint anthony
# Processing Record 34 of set 7 || kuruman
# Processing Record 35 of set 7 || quelimane
# Processing Record 36 of set 7 || chapeco
# Processing Record 37 of set 7 || mogadishu
# Processing Record 38 of set 7 || quartucciu
# Processing Record 39 of set 7 || garowe
# Processing Record 40 of set 7 || morococha
# Processing Record 41 of set 7 || heze
# Processing Record 42 of set 7 || ylivieska
# Processing Record 43 of set 7 || nampa
# Processing Record 44 of set 7 || teknaf
# Processing Record 45 of set 7 || xiaoshi
# Processing Record 46 of set 7 || barranca de upia
# Processing Record 47 of set 7 || mecca
# City not found skipping...
# Processing Record 48 of set 7 || ust-bolsheretsk
# Processing Record 49 of set 7 || coquimbo
# Processing Record 0 of set 8 || praia
# Processing Record 1 of set 8 || leningradskiy
# Processing Record 2 of set 8 || nome
# City not found skipping...
# Processing Record 3 of set 8 || rungata
# Processing Record 4 of set 8 || poum
# Processing Record 5 of set 8 || hamilton
# Processing Record 6 of set 8 || rochelle
# Processing Record 7 of set 8 || belaya gora
# Processing Record 8 of set 8 || parati
# Processing Record 9 of set 8 || hay river
# City not found skipping...
# Processing Record 10 of set 8 || westpunt
# Processing Record 11 of set 8 || otrado-kubanskoye
# City not found skipping...
# Processing Record 12 of set 8 || bac can
# Processing Record 13 of set 8 || fasa
# Processing Record 14 of set 8 || cutlerville
# Processing Record 15 of set 8 || ahuimanu
# Processing Record 16 of set 8 || vao
# Processing Record 17 of set 8 || salmas
# Processing Record 18 of set 8 || nola
# Processing Record 19 of set 8 || artyom
# Processing Record 20 of set 8 || ilhabela
# Processing Record 21 of set 8 || geraldton
# Processing Record 22 of set 8 || enshi
# Processing Record 23 of set 8 || saldanha
# Processing Record 24 of set 8 || elban
# Processing Record 25 of set 8 || jumla
# Processing Record 26 of set 8 || griffith
# Processing Record 27 of set 8 || sorland
# Processing Record 28 of set 8 || catalina foothills
# Processing Record 29 of set 8 || ikwiriri
# Processing Record 30 of set 8 || san cristobal
# Processing Record 31 of set 8 || sapang buho
# Processing Record 32 of set 8 || imbituba
# Processing Record 33 of set 8 || wuwei
# Processing Record 34 of set 8 || talcahuano
# Processing Record 35 of set 8 || conde
# Processing Record 36 of set 8 || taoudenni
# Processing Record 37 of set 8 || sao filipe
# Processing Record 38 of set 8 || vardo
# Processing Record 39 of set 8 || skjervoy
# Processing Record 40 of set 8 || cabot
# Processing Record 41 of set 8 || pueblo
# Processing Record 42 of set 8 || linxia
# Processing Record 43 of set 8 || poronaysk
# Processing Record 44 of set 8 || xam nua
# Processing Record 45 of set 8 || christchurch
# Processing Record 46 of set 8 || longyearbyen
# Processing Record 47 of set 8 || bere
# Processing Record 48 of set 8 || kargil
# Processing Record 49 of set 8 || jian
# Processing Record 0 of set 9 || kayerkan
# Processing Record 1 of set 9 || axim
# City not found skipping...
# Processing Record 2 of set 9 || akyab
# Processing Record 3 of set 9 || tautira
# Processing Record 4 of set 9 || arlit
# Processing Record 5 of set 9 || terrace
# Processing Record 6 of set 9 || juarez
# Processing Record 7 of set 9 || progreso
# Processing Record 8 of set 9 || mar del plata
# Processing Record 9 of set 9 || tres palos
# Processing Record 10 of set 9 || lompoc
# Processing Record 11 of set 9 || dudinka
# Processing Record 12 of set 9 || zhangye
# Processing Record 13 of set 9 || wattegama
# Processing Record 14 of set 9 || chingirlau
# Processing Record 15 of set 9 || teya
# Processing Record 16 of set 9 || talnakh
# Processing Record 17 of set 9 || lazaro cardenas
# Processing Record 18 of set 9 || komsomolskiy
# Processing Record 19 of set 9 || dickinson
# Processing Record 20 of set 9 || roseburg
# Processing Record 21 of set 9 || verkhnevilyuysk
# Processing Record 22 of set 9 || san jose
# City not found skipping...
# Processing Record 23 of set 9 || bolungarvik
# Processing Record 24 of set 9 || itarema
# Processing Record 25 of set 9 || constantine
# Processing Record 26 of set 9 || souillac
# Processing Record 27 of set 9 || portland
# Processing Record 28 of set 9 || deputatskiy
# Processing Record 29 of set 9 || taungdwingyi
# Processing Record 30 of set 9 || simao
# City not found skipping...
# Processing Record 31 of set 9 || da nang
# Processing Record 32 of set 9 || powell river
# Processing Record 33 of set 9 || copiapo
# Processing Record 34 of set 9 || emerald
# City not found skipping...
# Processing Record 35 of set 9 || ust-kamchatsk
# Processing Record 36 of set 9 || kathmandu
# Processing Record 37 of set 9 || rawatsar
# Processing Record 38 of set 9 || sanchez
# Processing Record 39 of set 9 || yazman
# Processing Record 40 of set 9 || hambantota
# Processing Record 41 of set 9 || tapes
# Processing Record 42 of set 9 || sokolo
# Processing Record 43 of set 9 || hami
# Processing Record 44 of set 9 || padang
# Processing Record 45 of set 9 || brae
# City not found skipping...
# Processing Record 46 of set 9 || bac lieu
# Processing Record 47 of set 9 || alice springs
# Processing Record 48 of set 9 || takhtamygda
# Processing Record 49 of set 9 || trollhattan
# Processing Record 0 of set 10 || sinnamary
# Processing Record 1 of set 10 || vila velha
# Processing Record 2 of set 10 || rypefjord
# Processing Record 3 of set 10 || kushiro
# Processing Record 4 of set 10 || soltsy
# Processing Record 5 of set 10 || biak
# City not found skipping...
# Processing Record 6 of set 10 || bur gabo
# Processing Record 7 of set 10 || mama
# Processing Record 8 of set 10 || antigonish
# City not found skipping...
# Processing Record 9 of set 10 || malwan
# Processing Record 10 of set 10 || sao joao da barra
# Processing Record 11 of set 10 || belyy yar
# City not found skipping...
# Processing Record 12 of set 10 || samusu
# Processing Record 13 of set 10 || upata
# City not found skipping...
# Processing Record 14 of set 10 || alotau
# Processing Record 15 of set 10 || sitka
# Processing Record 16 of set 10 || lakeside
# Processing Record 17 of set 10 || seddon
# Processing Record 18 of set 10 || parabel
# Processing Record 19 of set 10 || atar
# Processing Record 20 of set 10 || ravar
# Processing Record 21 of set 10 || odder
# Processing Record 22 of set 10 || obidos
# Processing Record 23 of set 10 || tagusao
# City not found skipping...
# Processing Record 24 of set 10 || longlac
# Processing Record 25 of set 10 || miranda
# Processing Record 26 of set 10 || inta
# Processing Record 27 of set 10 || avera
# Processing Record 28 of set 10 || puerto carreno
# City not found skipping...
# Processing Record 29 of set 10 || karaul
# Processing Record 30 of set 10 || puri
# Processing Record 31 of set 10 || bandarbeyla
# Processing Record 32 of set 10 || arenys de mar
# Processing Record 33 of set 10 || rio grande
# Processing Record 34 of set 10 || graham
# Processing Record 35 of set 10 || cayenne
# Processing Record 36 of set 10 || atambua
# Processing Record 37 of set 10 || honiara
# Processing Record 38 of set 10 || sergeyevka
# Processing Record 39 of set 10 || glasgow
# Processing Record 40 of set 10 || krasnoborsk
# Processing Record 41 of set 10 || clyde river
# City not found skipping...
# Processing Record 42 of set 10 || marcona
# Processing Record 43 of set 10 || pochutla
# Processing Record 44 of set 10 || fernley
# City not found skipping...
# Processing Record 45 of set 10 || rolim de moura
# Processing Record 46 of set 10 || beira
# Processing Record 47 of set 10 || osakarovka
# Processing Record 48 of set 10 || najran
# Processing Record 49 of set 10 || nabire
# City not found skipping...
# Processing Record 0 of set 11 || naftah
# Processing Record 1 of set 11 || oum hadjer
# Processing Record 2 of set 11 || kupang
# Processing Record 3 of set 11 || tarashcha
# Processing Record 4 of set 11 || trelew
# City not found skipping...
# Processing Record 5 of set 11 || jibuti
# Processing Record 6 of set 11 || puebloviejo
# Processing Record 7 of set 11 || jiuquan
# Processing Record 8 of set 11 || wittenbach
# Processing Record 9 of set 11 || banepa
# City not found skipping...
# Processing Record 10 of set 11 || cansancao
# Processing Record 11 of set 11 || galveston
# Processing Record 12 of set 11 || dossor
# Processing Record 13 of set 11 || rocha
# Processing Record 14 of set 11 || iquique
# City not found skipping...
# Processing Record 15 of set 11 || amderma
# Processing Record 16 of set 11 || iquitos
# Processing Record 17 of set 11 || udachnyy
# Processing Record 18 of set 11 || bulgan
# Processing Record 19 of set 11 || eyl
# Processing Record 20 of set 11 || yerbogachen
# Processing Record 21 of set 11 || naze
# Processing Record 22 of set 11 || shingu
# City not found skipping...
# Processing Record 23 of set 11 || karamay
# Processing Record 24 of set 11 || kokoda
# Processing Record 25 of set 11 || port shepstone
# Processing Record 26 of set 11 || kruisfontein
# Processing Record 27 of set 11 || katsuura
# Processing Record 28 of set 11 || pahrump
# Processing Record 29 of set 11 || grand gaube
# Processing Record 30 of set 11 || yunyang
# Processing Record 31 of set 11 || el playon
# Processing Record 32 of set 11 || oranjemund
# Processing Record 33 of set 11 || saravan
# Processing Record 34 of set 11 || benicarlo
# Processing Record 35 of set 11 || katangli
# Processing Record 36 of set 11 || hobyo
# Processing Record 37 of set 11 || lulea
# Processing Record 38 of set 11 || le port
# Processing Record 39 of set 11 || plattsburgh
# Processing Record 40 of set 11 || durban
# Processing Record 41 of set 11 || chihuahua
# Processing Record 42 of set 11 || manono
# City not found skipping...
# Processing Record 43 of set 11 || papasquiaro
# Processing Record 44 of set 11 || ouallam
# Processing Record 45 of set 11 || anloga
# Processing Record 46 of set 11 || kuala lipis
# Processing Record 47 of set 11 || muzhi
# Processing Record 48 of set 11 || tungor
# Processing Record 49 of set 11 || pingliang
# Processing Record 0 of set 12 || namibe
# Processing Record 1 of set 12 || muscat
# Processing Record 2 of set 12 || liangxiang
# Processing Record 3 of set 12 || ust-ilimsk
# Processing Record 4 of set 12 || trzcianka
# Processing Record 5 of set 12 || erdenet
# Processing Record 6 of set 12 || kalabo
# Processing Record 7 of set 12 || at-bashi
# Processing Record 8 of set 12 || miles city
# Processing Record 9 of set 12 || rapu-rapu
# City not found skipping...
# Processing Record 10 of set 12 || zhanatas
# Processing Record 11 of set 12 || vostok
# Processing Record 12 of set 12 || kamenka
# City not found skipping...
# Processing Record 13 of set 12 || rawannawi
# City not found skipping...
# Processing Record 14 of set 12 || jujuy
# Processing Record 15 of set 12 || te anau
# City not found skipping...
# Processing Record 16 of set 12 || taburi
# Processing Record 17 of set 12 || zomba
# Processing Record 18 of set 12 || champasak
# Processing Record 19 of set 12 || nanortalik
# Processing Record 20 of set 12 || pisco
# Processing Record 21 of set 12 || kabare
# Processing Record 22 of set 12 || meadow lake
# Processing Record 23 of set 12 || kloulklubed
# Processing Record 24 of set 12 || rantepao
# City not found skipping...
# Processing Record 25 of set 12 || palaiokhora
# Processing Record 26 of set 12 || kidal
# Processing Record 27 of set 12 || pacific grove
# Processing Record 28 of set 12 || mocuba
# Processing Record 29 of set 12 || yar-sale
# Processing Record 30 of set 12 || grindavik
# Processing Record 31 of set 12 || samarai
# Processing Record 32 of set 12 || ballina
# Processing Record 33 of set 12 || nagua
# Processing Record 34 of set 12 || amga
# Processing Record 35 of set 12 || divnomorskoye
# City not found skipping...
# Processing Record 36 of set 12 || barawe
# Processing Record 37 of set 12 || aborlan
# Processing Record 38 of set 12 || havre-saint-pierre
# City not found skipping...
# Processing Record 39 of set 12 || manzil tamim
# Processing Record 40 of set 12 || pangai
# Processing Record 41 of set 12 || luanda
# Processing Record 42 of set 12 || lewistown
# Processing Record 43 of set 12 || milkovo
# Processing Record 44 of set 12 || zhoukou
# Processing Record 45 of set 12 || flinders
# Processing Record 46 of set 12 || barcarena
# Processing Record 47 of set 12 || buin
# Processing Record 48 of set 12 || kabalo
# Processing Record 49 of set 12 || ciudad bolivar
# Processing Record 0 of set 13 || chanthaburi

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
data_df=pd.DataFrame(city_data)
data_df.columns=["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Temp", "Wind Speed"]                      
data_df
# Out:
#                    City  Cloudiness Country        Date  Humidity    Lat  \
# 0                camalu           0      MX  1569453869        83  30.85
# 1               ushuaia          40      AR  1569453869        69 -54.81
# 2                bethel          40      US  1569453870        61  60.79
# 3              thompson          20      CA  1569453870        34  55.74
# 4               kahului          40      US  1569453590        52  20.89
# 5               ahipara          57      NZ  1569453870        87 -35.17
# 6             esperance         100      AU  1569453871        93 -33.86
# 7                sangar          89      RU  1569453871        81  63.92
# 8         makakilo city          90      US  1569453708       100  21.35
# 9            chokurdakh          56      RU  1569453871        72  70.62
# 10            yeletskiy          56      RU  1569453871        72  70.62
# 11             lilongwe          75      MW  1569453872        77 -13.97
# 12         punta arenas           0      CL  1569453872        60 -53.16
# 13            saskylakh          64      RU  1569453872        94  71.97
# 14               atuona          81      PF  1569453873        77  -9.80
# 15        vreed en hoop          81      PF  1569453873        77  -9.80
# 16               eureka           1      US  1569453605        39  40.80
# 17            mahebourg          20      MU  1569453873        94 -20.41
# 18               dikson          90      RU  1569453849        94  73.51
# 19           santa cruz          87      BR  1569453874        74  -6.22
# 20               hobart          75      AU  1569453750        58 -42.88
# 21                pevek          72      RU  1569453827        76  69.70
# 22             tsihombe          72      RU  1569453827        76  69.70
# 23                vaini         100      IN  1569453751        94  15.34
# 24            san ramon          75      NI  1569453875        94  12.92
# 25             luderitz          13      NA  1569453875        36 -26.65
# 26            bathsheba          20      BB  1569453762        78  13.22
# 27               mantua          22      IT  1569453875        93  45.16
# 28            atyuryevo          22      IT  1569453875        93  45.16
# 29                ancud           0      CL  1569453876        93 -41.87
# ..                  ...         ...     ...         ...       ...    ...
# 570              kabare         100      RW  1569454009        95  -1.65
# 571         meadow lake          40      CA  1569454009        71  54.13
# 572         kloulklubed          75      PW  1569454010        83   7.04
# 573            rantepao          80      ID  1569454010        75  -2.97
# 574         palaiokhora          80      ID  1569454010        75  -2.97
# 575               kidal           0      ML  1569454010        14  18.44
# 576       pacific grove           1      US  1569454011        21  36.62
# 577              mocuba         100      MZ  1569453793        68 -16.84
# 578            yar-sale         100      RU  1569454011        86  66.83
# 579           grindavik          75      IS  1569453880        93  63.84
# 580             samarai          83      PG  1569454011        92 -10.62
# 581             ballina          52      IE  1569454012        91  54.11
# 582               nagua          75      DO  1569454012        94  19.37
# 583                amga           1      RU  1569454012        82  60.89
# 584       divnomorskoye         100      RU  1569454013        82  44.50
# 585              barawe         100      RU  1569454013        82  44.50
# 586             aborlan          20      PH  1569454013        83   9.44
# 587  havre-saint-pierre          90      CA  1569454013        93  50.23
# 588        manzil tamim          90      CA  1569454013        93  50.23
# 589              pangai          75      TO  1569453866        65 -19.80
# 590              luanda          40      AO  1569454014        94  -8.83
# 591           lewistown           1      US  1569454014        47  40.39
# 592             milkovo          75      BG  1569454014        93  41.53
# 593             zhoukou          20      CN  1569454015        43  33.63
# 594            flinders          40      AU  1569454015        63 -34.58
# 595           barcarena          75      BR  1569454015        88  -1.51
# 596                buin           0      CL  1569454016        40 -33.73
# 597              kabalo          98      CD  1569454016        81  -6.05
# 598      ciudad bolivar         100      VE  1569454016        72   8.12
# 599         chanthaburi          51      TH  1569454016        70  12.61
#
#         Lng    Temp  Wind Speed
# 0   -116.07  293.19        0.85
# 1    -68.31  277.15        4.10
# 2   -161.76  281.15        5.70
# 3    -97.86  283.15        6.20
# 4   -156.47  305.15        2.10
# 5    173.16  288.71       12.44
# 6    121.89  287.15        0.50
# 7    127.47  277.46        3.34
# 8   -158.09  300.93        2.60
# 9    147.90  271.46        3.74
# 10   147.90  271.46        3.74
# 11    33.79  288.15       10.30
# 12   -70.91  279.15        9.80
# 13   114.09  274.83        3.20
# 14  -139.03  299.56        9.16
# 15  -139.03  299.56        9.16
# 16  -124.16  305.37        7.20
# 17    57.70  294.26        2.10
# 18    80.55  275.15        4.17
# 19   -36.02  294.26        9.28
# 20   147.33  286.48        4.60
# 21   170.27  274.40        4.03
# 22   170.27  274.40        4.03
# 23    74.49  297.10        1.07
# 24   -85.84  295.15        0.93
# 25    15.16  307.15        7.20
# 26   -59.52  301.15        4.10
# 27    10.79  291.15        0.50
# 28    10.79  291.15        0.50
# 29   -73.83  284.15        2.60
# ..      ...     ...         ...
# 570   29.38  287.36        1.02
# 571 -108.44  284.15        8.20
# 572  134.26  301.15        2.73
# 573  119.90  292.62        1.20
# 574  119.90  292.62        1.20
# 575    1.41  304.87        3.69
# 576 -121.92  310.37        4.60
# 577   36.99  291.47        4.68
# 578   70.83  274.95        5.01
# 579  -22.43  285.15        4.60
# 580  150.67  297.49        3.29
# 581   -9.15  288.15        1.34
# 582  -69.85  303.15        1.50
# 583  131.98  276.95        2.05
# 584   38.13  289.10        3.49
# 585   38.13  289.10        3.49
# 586  118.55  300.15        2.10
# 587  -63.60  281.15        6.20
# 588  -63.60  281.15        6.20
# 589 -174.35  298.15        4.10
# 590   13.24  296.15        1.50
# 591  -90.15  299.15        3.60
# 592   24.68  293.71        1.00
# 593  114.64  296.06        1.67
# 594  150.85  293.71        1.00
# 595  -48.62  298.15        2.60
# 596  -70.74  294.15        2.10
# 597   26.92  296.64        2.81
# 598  -63.55  300.90        0.71
# 599  102.11  302.59        4.95
#
# [600 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(data_df["Lat"],data_df["Temp"],c="lightblue",edgecolor='black')
plt.title(f"City Latitude vs Max Temperature ({date})")
plt.ylabel("Max Temprature (F)")
plt.xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(data_df["Lat"],data_df['Humidity'],c="lightblue",edgecolor='black')
plt.title(f"City Latitude vs Humidity ({date})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(data_df["Lat"],data_df['Cloudiness'],c="lightblue",edgecolor='black')
plt.title(f"City Latitude vs Cloudiness ({date})")
plt.ylabel("Clouds (%)")
plt.xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(data_df["Lat"],data_df['Wind Speed'],c="lightblue",edgecolor='black')
plt.title(f"City Latitude vs Cloudiness ({date})")
plt.ylabel("Clouds (%)")
plt.xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %%
#Save the data into the a csv called worldcityweather

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
